# %%
import pandas as pd
import seaborn as sn

# %%
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sn.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
names = sn.get_dataset_names()

# %%
names
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
names = sn.get_dataset_names()
for i in range(0, len(names)):    
    print('\x1b[6;30;42m' + names[i] + '\x1b[0m')
    print(sn.load_dataset(names[i]).info())
    print('-'*80)
# Out:
# anagrams
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   subidr  20 non-null     int64
#  1   attnr   20 non-null     object
#  2   num1    20 non-null     int64
#  3   num2    20 non-null     float64
#  4   num3    20 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 928.0+ bytes
# None
# --------------------------------------------------------------------------------
# anscombe
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB
# None
# ...

# %%
df_taxis = sn.load_dataset('taxis')
df_taxis.head(3)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan

# %%
df_taxis.drop('pickup', axis=1, inplace = True)
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %% [markdown]
# ## My dataset
# #### Questions
# * 1 quetsion
# * 2 question

# %%
df_taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
df_taxis['passengers'].value_counts()
# Out:
# 1    4678
# 2     876
# 5     277
# 3     243
# 6     153
# 4     110
# 0      96
# Name: passengers, dtype: int64

# %%
# print(df_taxis['pickup_zone'].value_counts().describe())
df_taxis['pickup_zone'].value_counts().plot(kind = 'hist', bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_taxis[df_taxis['passengers'] == 0]
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 7     2019-03-22 12:47:13  2019-03-22 12:58:17           0       1.4   8.5
# 14    2019-03-27 12:13:34  2019-03-27 12:25:48           0       2.9  11.5
# 41    2019-03-24 18:42:56  2019-03-24 19:09:00           0       4.5  20.0
# 92    2019-03-28 07:05:19  2019-03-28 07:41:14           0      10.6  33.5
# 117   2019-03-23 09:39:25  2019-03-23 09:56:45           0       3.6  15.5
# ...                   ...                  ...         ...       ...   ...
# 5187  2019-03-05 00:42:20  2019-03-05 00:51:13           0       2.2   9.0
# 5207  2019-03-19 12:30:27  2019-03-19 12:49:12           0       2.1  13.0
# 5280  2019-03-15 23:33:56  2019-03-15 23:51:39           0       3.6  14.0
# 5741  2019-03-30 13:29:38  2019-03-30 13:48:18           0       3.0  14.5
# 6080  2019-03-15 20:42:08  2019-03-15 20:42:18           0       0.0   8.0
#
# ...

# %%
df_taxis.groupby('pickup_zone')[['distance', 'fare']].median().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='pickup_zone'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df_taxis, alpha=0.5, figsize = (18,18));

# %%
df_taxis.plot(figsize = (15, 7), y = ['distance', 'fare', 'tip'])
# Out:
# <AxesSubplot:>

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import colormaps
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1424/1797706776.py in <module>
# ----> 1 from matplotlib import colormaps
#
# ImportError: cannot import name 'colormaps' from 'matplotlib' (C:\Users\studenta\Anaconda3\lib\site-packages\matplotlib\__init__.py)

# %%
df_taxis.describe()
# Out:
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# std       1.203768     3.827867    11.551804     2.44856     1.415267
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
#
#              total
# count  6433.000000
# mean     18.517794
# std      13.815570
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000

# %%
df_taxis.plot.scatter(x='distance', y='fare', 
                      c= 'passengers', cmap="coolwarm_r",
                      s = 'tip',
                      figsize = (10,6))
# Out:
# <AxesSubplot:xlabel='distance', ylabel='fare'>

# %%
df_taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
df_taxis.groupby('pickup_zone')['tip'].mean()
# Out:
# pickup_zone
# Allerton/Pelham Gardens    0.000000
# Alphabet City              2.157778
# Astoria                    0.546769
# Auburndale                 0.000000
# Battery Park               0.000000
#                              ...
# Woodlawn/Wakefield         0.000000
# Woodside                   0.847308
# World Trade Center         2.412917
# Yorkville East             1.992958
# Yorkville West             1.794020
# Name: tip, Length: 194, dtype: float64

# %%
df_taxis.groupby('pickup_zone')['tip'].mean().plot(figsize = (15, 6), rot = 90)
# Out:
# <AxesSubplot:xlabel='pickup_zone'>
