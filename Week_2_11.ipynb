# %% [markdown]
# ## <center>Week 2</center>
#
# ### <center>Matplotlib</center>
# https://matplotlib.org/
#
# ### Matplotlib plotiing basics
#
#
# #### Layers
#
# * Scripting Layer: matplotlib.pyplot\
# * Artist Layer: matplotlib.artist\
# * Backend Layer: matplotlib.backend.bases
#
# #### Application interfaces APIs
#
# * pyplot interface (function-based, implicit)
# * Axes interface (object-based, explicit)
#
#
# #### Basic graphs
#
#
# * Linear plot
# * Scatter plot
# * Histogram
# * Barchart
# * Boxplot
# * Correlation plots
#
# #### Settings
#
# * Title
# * Labels
# * Legends
#
# #### Useful links
# How write math expressions in text https://matplotlib.org/2.0.2/users/mathtext.html \
# pyplot.plot() arguments and parameters
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html \
# Colors in matplotlib
# https://matplotlib.org/stable/users/explain/colors/colors.html

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### pyplot interface (procedural, inheritance of matlab))

# %%
x = np.arange(0,10,0.5)
y = x**2
plt.plot(x, y)
# plt.show()

# %%
plt.plot(x,y,
         color='blue', #'b', '#1f77b4', (0,0,1)
         marker='o', 
         linestyle='dashed', # '--'
        )

# %%
plt.plot(x,y,'o--b'); # fmt = '[marker][line][color]'

# %%
# Add title, lables, limits
plt.plot(x,y,'o--b',markeredgecolor = 'r',)
plt.title('f(x)=$x^2$',
         family = 'serif',
         color = 'r',
         weight = 'bold',
         size = 16) 
plt.xlabel('x')
plt.ylabel('f(x)');

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

# %%
plt.figure(figsize=(8,5))
plt.plot(x,y,'o--b',markeredgecolor = 'r', markersize = 7,
         label = '$f(x)=x^2$')
plt.title('f(x)=$x^2$',
         family = 'serif',
         color = 'g',
         weight = 'bold',
         size = 16) 
plt.xlabel('x', fontdict = font)
plt.ylabel('f(x)', fontdict = font)
plt.legend(loc='lower right')
plt.grid()
#plt.figure(figsize=(8,5));

# %%
x = np.arange(0,10,0.5)
y = x**2
z = (-1*x**2)+20

plt.figure(figsize=(8,5))
plt.plot(x,y,'o--b',label = '$f(x)=x^2$')
plt.plot(x,z,'o:r',label = '$f(x)=-x^2+20$')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.suptitle('Plots for my functions', fontsize=30)

plt.subplot(2,2,3)
plt.plot(x,y,'o--b')
plt.title('$f(x)=x^2$')

plt.subplot(2,2,4)
plt.plot(x,z,'o:r')
plt.title('$f(x)=-x^2+20$')

plt.subplot(2,1,1)
plt.plot(x,y,'o--b',label = '$f(x)=x^2$')
plt.plot(x,z,'o:r',label = '$f(x)=-x^2+20$')
plt.title('$f(x)=-x^2+20$ and $f(x)=x^2$')
plt.tight_layout()

# %% [markdown]
# ### Axes interface (object-oriented)

# %% [markdown]
# #### Matplotlib figures, axis and other parts of figure
# https://matplotlib.org/stable/users/explain/quick_start.html#parts-of-a-figure

# %%
x = np.arange(0,10,0.5)
y = x**2

fig = plt.figure(figsize = (8,5))
ax = fig.add_axes([0.1,0.1,0.9,0.9])

ax.plot(x,y, color = 'blue', lw = 2, ls='--',
        marker = 'o', markersize = 8, markerfacecolor = 'r',
        markeredgecolor = 'y', markeredgewidth = 3)

ax.set_title('f(x)=$x^2$', family = 'serif',color = 'r',
         weight = 'bold',size = 16) 
ax.set_xlabel('x', fontdict = font)
ax.set_ylabel('y', fontdict = font)
ax.grid(color = 'r', ls = '--') 
ax.set_facecolor('0.9')

plt.show()
fig.savefig('my_plot', dpi = 100, bbox_inches='tight')

# %%
x = np.arange(0,10,0.5)
y = x**2
z = (-1*x**2)+20

plt.figure(figsize=(8,5))
plt.plot(x,y,'o--b',label = '$f(x)=x^2$')
plt.plot(x,z,'o:r',label = '$f(x)=-x^2+20$')
plt.legend()
plt.show()

# %%
x = np.arange(0,10,0.5)
y = x**2
z = (-1*x**2)+20

fig, ax = plt.subplots(figsize = (8,5))
ax.plot(x,y, 'o--b', label = '$f(x)=x^2$')
ax.plot(x,z, 'o:r', label = '$f(x)=-x^2+20$')
ax.legend(loc = 'best')
ax.set_title('Show two lines', 
             family = 'arial', color = '0.5',
             weight = 'bold',
             size = 16)
ax.set_xlabel('x', family = 'arial', size = 16)
ax.set_ylabel('y', family = 'arial', size = 16, rotation = 0)
ax.set_facecolor('0.9')

# add plot in plot
ax1 = fig.add_axes([0.65,0.4,0.2,0.2])
ax1.plot(x,y,x,z)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_xlim([2,4])
ax1.set_ylim([0,20])
ax1.text(2.7,15, '(3.2, 10)')
ax1.set_facecolor('0.7')
plt.show()

# %%
fig_1 = plt.figure(figsize=(12,8), dpi=100, facecolor='gray') 
axes_1 = fig_1.add_axes([0,0,1,1]) #set xmin, ymin, width, and height 
axes_2 = fig_1.add_axes([0.2,0.2,0.5,0.5], facecolor='yellow')
axes_3 = fig_1.add_axes([0.3,0.4,0.5,0.5], facecolor='green')
axes_3.plot(x,y, color = 'r')

# %% [markdown]
# ### Real data practice

# %%
import seaborn as sn
df = sn.load_dataset('taxis')
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %% [markdown]
# #### Line graph
# matplotlib.pyplot.plot(
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
df_1 = df.sort_values('distance')

x = np.array(df_1.distance)
y = np.array(df_1.fare)
y1 = np.array(df_1.tip)

fig, (ax_dist_fare, ax_dist_tip) = plt.subplots(figsize=(10,6),
                                               ncols = 1,
                                               nrows = 2)
ax_dist_fare.plot(x,y, 'mo')
ax_dist_tip.plot(x,y1, 'co')

# %%
len(df_1[df_1['tip'] == 0])
# Out:
# 2311

# %%
print('Rides with 0 tip')
print(df_1.loc[(df['tip'] == 0),:].describe())
print('-'*60)
print('Rides with tip')
print(df_1.loc[(df['tip'] != 0),:].describe())
# Out:
# Rides with 0 tip
#                               pickup                        dropoff  \
# count                           2311                           2311
# mean   2019-03-16 09:10:19.448290816  2019-03-16 09:25:25.885763584
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 18:51:31     2019-03-08 18:57:04.500000
# 50%              2019-03-16 02:40:48            2019-03-16 02:57:11
# 75%       2019-03-23 18:21:45.500000            2019-03-23 18:45:34
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare     tip        tolls        total
# count  2311.000000  2311.000000  2311.000000  2311.0  2311.000000  2311.000000
# mean      1.489831     3.225751    13.736612     0.0     0.301086    16.643064
# min       0.000000     0.000000     1.000000     0.0     0.000000     1.300000
# ...

# %%
df_1.groupby('tolls').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
# ...

# %%
df_by_tolls = df_1.groupby('tolls').mean()
df_by_tolls.plot(figsize = (12,8))
# Out:
# <AxesSubplot:xlabel='tolls'>

# %%
df_by_tolls[['distance','fare','tip']].plot(figsize = (15,6),
                                           ylim = [0,40])
# Out:
# <AxesSubplot:xlabel='tolls'>

# %%
df_by_tolls.plot(subplots=True, figsize = (15,6))
plt.tight_layout();

# %%
print(df_1.groupby(['tolls', 'color']).mean())
df_1.groupby(['tolls', 'color']).mean().plot(figsize = (15,6))
# Out:
#               passengers   distance        fare        tip       total
# tolls color
# 0.00  green     1.255864   2.899584   12.629062   0.795629   14.820640
#       yellow    1.592420   2.352455   11.237769   1.901638   16.581827
# 2.64  green     1.000000  11.515000   34.590000   3.595000   41.675000
#       yellow    2.000000  12.613333   43.833333   2.316667   49.590000
# 4.75  green     1.000000   8.200000   26.000000   0.000000   34.800000
# 5.54  yellow    1.500000  10.490000   34.500000   8.670000   52.010000
# 5.75  yellow    1.000000   7.800000   26.000000   7.200000   43.250000
# 5.76  green     1.085714  14.184286   42.475429   0.584571   49.605714
#       yellow    1.570934  13.012837   40.323183   7.000035   56.495675
# 6.12  yellow    1.000000  15.460000   47.250000   4.000000   59.920000
# 8.40  yellow    1.000000  24.200000   67.500000   0.000000   76.700000
# 8.50  yellow    1.000000   0.000000   52.000000  13.660000   81.960000
# ...

# %%
df.groupby(['pickup_borough', 'color']).count()
# Out:
#                        pickup  dropoff  passengers  distance  fare   tip  \
# pickup_borough color
# Bronx          green       83       83          83        83    83    83
#                yellow      16       16          16        16    16    16
# Brooklyn       green      313      313         313       313   313   313
#                yellow      70       70          70        70    70    70
# Manhattan      green      294      294         294       294   294   294
#                yellow    4974     4974        4974      4974  4974  4974
# Queens         green      288      288         288       288   288   288
#                yellow     369      369         369       369   369   369
#
#                        tolls  total  payment  pickup_zone  dropoff_zone  \
# pickup_borough color
# Bronx          green      83     83       83           83            83
#                yellow     16     16       16           16            16
# ...

# %%
df.groupby(['pickup_borough', 'color'])[['fare', 'tip']].mean()
# Out:
#                             fare       tip
# pickup_borough color
# Bronx          green   20.470241  0.177229
#                yellow  23.742500  0.000000
# Brooklyn       green   16.048243  0.896230
#                yellow  18.634000  1.279857
# Manhattan      green   10.583673  1.042211
#                yellow  11.186534  1.992589
# Queens         green   13.635139  0.623264
#                yellow  33.753767  4.926341

# %%
(df.groupby(['pickup_borough', 'color'])[['fare', 'tip']].mean()).plot(kind = 'bar')
(df.groupby(['pickup_borough', 'color'])[['fare', 'tip']].mean()).plot(rot = 90)
plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
df.corr()
# Out:
#             passengers  distance      fare       tip     tolls     total
# passengers    1.000000  0.009411  0.007637  0.021099 -0.002903  0.015708
# distance      0.009411  1.000000  0.920108  0.452589  0.635267  0.904676
# fare          0.007637  0.920108  1.000000  0.488612  0.609307  0.974358
# tip           0.021099  0.452589  0.488612  1.000000  0.413619  0.646186
# tolls        -0.002903  0.635267  0.609307  0.413619  1.000000  0.683142
# total         0.015708  0.904676  0.974358  0.646186  0.683142  1.000000

# %%
plt.matshow(df.corr())

# %% [markdown]
# ### Histogram
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %%
plt.figure(figsize = (12,8))
plt.hist(df.fare, 
         bins = 30, 
         density = True,
        #  stacked = True,
        #  range = (10, 50),
        #  bottom = 200,
        #  cumulative = True,
        #  histtype = 'step',
        #  log = True,

        #  orientation = 'horizontal',

         color = 'c',
         edgecolor='m',
        #  linewidth=1
        )
plt.xlabel("Fare",fontsize = 16)
plt.title("Distribution of fare", fontsize = 16, weight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (12,8))
plt.hist([df.distance, df.fare], 
         bins = 20, 
        #  density = True,
         stacked = True,
        #  range = (0, 100),
        #  bottom = 200,
        #  cumulative = True,
        #  histtype = 'step',
        #  log = True,
        #  orientation = 'horizontal',
        #  color = 'r',
        #  edgecolor='red',
        #  linewidth=1,
         label = ['Fare', 'Distance'],
         alpha=0.65

        )
plt.xlabel("Fare",fontsize = 16)
plt.title("Distribution of fare", fontsize = 16, weight='bold')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Taxis dataset: calculate ride duration

# %%
import pandas as pd
df_2 = df
df_2.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough   ride_duration  \
# ...

# %%
df_2['ride_duration'] = (pd.to_datetime(df_2.dropoff) -  pd.to_datetime(df_2.pickup)).astype('timedelta64[us]')
print(df_2.ride_duration)
df_2.ride_duration.hist()
# Out:
# 0      0 days 00:06:15
# 1      0 days 00:07:05
# 2      0 days 00:07:24
# 3      0 days 00:25:52
# 4      0 days 00:09:32
#              ...
# 6428   0 days 00:03:34
# 6429   0 days 00:56:23
# 6430   0 days 00:19:07
# 6431   0 days 00:05:04
# 6432   0 days 00:16:40
# Name: ride_duration, Length: 6433, dtype: timedelta64[us]
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# DTypePromotionError: The DType <class 'numpy.dtypes.TimeDelta64DType'> could not be promoted by <class 'numpy.dtypes.Float64DType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.TimeDelta64DType'>, <class 'numpy.dtypes.Float64DType'>)
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_2['fare_tip_ratio'] = round(df_2.tip/df_2.fare, 2)
print(df_2.fare_tip_ratio)
df_2.fare_tip_ratio.hist()
# Out:
# 0       0.31
# 1       0.00
# 2       0.31
# 3       0.23
# 4       0.12
#         ...
# 6428    0.24
# 6429    0.00
# 6430    0.00
# 6431    0.00
# 6432    0.22
# Name: fare_tip_ratio, Length: 6433, dtype: float64
# <Axes: >

# %%
df_2.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough   ride_duration  \
# ...

# %%
df_2['fare_tip_ratio'].hist(bins=100,  
                            density=True, 
                            range=[0.001, 0.9],
                           figsize = (15,8))
# Out:
# <Axes: >

# %% [markdown]
# ### Bar chart

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,5))
ax[0,0].hist(df_2.ride_duration, bins = 20)
ax[0,0].grid(None)

ax[0,1].hist(df_2.fare_tip_ratio)
ax[1,0].scatter(df_2.ride_duration, df_2.fare_tip_ratio)
ax[1,1].scatter(df_2.ride_duration.sort_values(), df_2.fare_tip_ratio)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# DTypePromotionError: The DType <class 'numpy.dtypes.TimeDelta64DType'> could not be promoted by <class 'numpy.dtypes.Float64DType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.TimeDelta64DType'>, <class 'numpy.dtypes.Float64DType'>)
#
# The above exception was the direct cause of the following exception:
#
# UFuncTypeError                            Traceback (most recent call last)
# /Users/vahan.sahakyan/dv/data-visualization/Week_2_11.ipynb Cell 45 line 2
#       <a href='vscode-notebook-cell:/Users/vahan.sahakyan/dv/data-visualization/Week_2_11.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = plt.subplots(2, 2, figsize=(15,5))
# ...

# %%
df_2.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough   ride_duration  \
# ...

# %%
df_3 = df_2[['pickup_borough', 'dropoff_borough', 'ride_duration']]
df_3.head()
# Out:
#   pickup_borough dropoff_borough   ride_duration
# 0      Manhattan       Manhattan 0 days 00:06:15
# 1      Manhattan       Manhattan 0 days 00:07:05
# 2      Manhattan       Manhattan 0 days 00:07:24
# 3      Manhattan       Manhattan 0 days 00:25:52
# 4      Manhattan       Manhattan 0 days 00:09:32

# %%
df_2.passengers.value_counts()
# Out:
# passengers
# 1    4678
# 2     876
# 5     277
# 3     243
# 6     153
# 4     110
# 0      96
# Name: count, dtype: int64

# %%
pass_tip = df_2.groupby('passengers')['fare_tip_ratio'].agg(['mean', 'var'])
pass_dist = df_2.groupby('passengers')['distance'].agg(['mean', 'var'])

# %%
print(pass_dist)
print(pass_tip)
# Out:
#                 mean        var
# passengers
# 0           2.960417  12.888311
# 1           3.019245  14.432253
# 2           2.978596  15.331140
# 3           3.135844  15.498491
# 4           2.936455  12.539238
# 5           2.964188  12.454581
# 6           3.488758  23.101469
#                 mean       var
# passengers
# 0           0.208438  0.020188
# 1           0.165184  0.021073
# 2           0.177409  0.022494
# 3           0.173827  0.023813
# 4           0.178818  0.017746
# 5           0.178231  0.021093
# 6           0.188627  0.020563

# %%
plt.bar(pass_tip.index, pass_tip['mean'],yerr = pass_tip['var'])
plt.bar(pass_dist.index, pass_dist['mean'])
# Out:
# <BarContainer object of 7 artists>

# %%
pass_tip_bor = df_2.groupby(['pickup_borough', 'passengers'])['fare_tip_ratio'].agg(['mean', 'var'])
pass_tip_bor
# Out:
#                                mean       var
# pickup_borough passengers
# Bronx          0           0.000000       NaN
#                1           0.011136  0.002286
#                2           0.000000  0.000000
#                3           0.000000       NaN
#                5           0.000000  0.000000
# Brooklyn       0           0.000000       NaN
#                1           0.074154  0.013595
#                2           0.097647  0.017243
#                3           0.176667  0.019547
#                4           0.240000       NaN
#                5           0.124444  0.016003
#                6           0.071429  0.011081
# Manhattan      0           0.211882  0.020818
#                1           0.185220  0.020597
#                2           0.188620  0.022692
#                3           0.182911  0.024392
#                4           0.180816  0.018717
#                5           0.193846  0.020780
#                6           0.204846  0.019438
# ...

# %%
noindex = pass_tip_bor.reset_index()

# %%
noindex
# Out:
#    pickup_borough  passengers      mean       var
# 0           Bronx           0  0.000000       NaN
# 1           Bronx           1  0.011136  0.002286
# 2           Bronx           2  0.000000  0.000000
# 3           Bronx           3  0.000000       NaN
# 4           Bronx           5  0.000000  0.000000
# 5        Brooklyn           0  0.000000       NaN
# 6        Brooklyn           1  0.074154  0.013595
# 7        Brooklyn           2  0.097647  0.017243
# 8        Brooklyn           3  0.176667  0.019547
# 9        Brooklyn           4  0.240000       NaN
# 10       Brooklyn           5  0.124444  0.016003
# 11       Brooklyn           6  0.071429  0.011081
# 12      Manhattan           0  0.211882  0.020818
# 13      Manhattan           1  0.185220  0.020597
# 14      Manhattan           2  0.188620  0.022692
# 15      Manhattan           3  0.182911  0.024392
# 16      Manhattan           4  0.180816  0.018717
# 17      Manhattan           5  0.193846  0.020780
# ...

# %%
Bronx = noindex[noindex['pickup_borough']=='Bronx']
Brooklyn = noindex[noindex['pickup_borough']=='Brooklyn']
Manhattan = noindex[noindex['pickup_borough']=='Manhattan']
Queens = noindex[noindex['pickup_borough']=='Queens']

# %%
Bronx
# Out:
#   pickup_borough  passengers      mean       var
# 0          Bronx           0  0.000000       NaN
# 1          Bronx           1  0.011136  0.002286
# 2          Bronx           2  0.000000  0.000000
# 3          Bronx           3  0.000000       NaN
# 4          Bronx           5  0.000000  0.000000

# %%
plt.figure(figsize = (15,8))
plt.bar(Bronx['passengers'], Bronx['mean'], label = 'Bronx', width = 0.25)
plt.bar(Brooklyn['passengers']+0.25, Brooklyn['mean'], label = 'Brooklyn', width = 0.25)
plt.bar(Manhattan['passengers']+0.5, Manhattan['mean'], label = 'Manhattan',width = 0.25)
plt.bar(Queens['passengers']+0.75, Queens['mean'], label = 'Queens',width = 0.25)
plt.xticks(np.arange(7)+0.5, ('0','1','2','3','4','5','6'),fontsize = 12, weight='bold' )
plt.yticks(rotation=25)

plt.legend()
plt.title('Mean tip/fare ratio for NYC boroughs by passengers number', fontsize = 16, weight='bold')
plt.show()

# %%
df_2.groupby(['pickup_borough'])[['distance', 'total']].mean().reset_index()
# Out:
#   pickup_borough  distance      total
# 0          Bronx  5.725859  22.765253
# 1       Brooklyn  4.058668  19.236240
# 2      Manhattan  2.349723  16.670507
# 3         Queens  7.465830  31.660107

# %%
bor = df_2.groupby(['pickup_borough'])[['distance', 'total']].mean().reset_index().iloc[:,0].values
dist = df_2.groupby(['pickup_borough'])[['distance', 'total']].mean().reset_index().iloc[:,1].values
total = df_2.groupby(['pickup_borough'])[['distance', 'total']].mean().reset_index().iloc[:,2].values

# %%
print(bor, dist, total)
# Out:
# ['Bronx' 'Brooklyn' 'Manhattan' 'Queens'] [5.72585859 4.05866841 2.34972285 7.46582953] [22.76525253 19.23624021 16.67050683 31.66010654]

# %%
plt.figure(figsize = (12,8))
plt.bar(bor, dist, label = 'Distance', bottom = total, width = 0.45)
plt.bar(bor, total, label = 'Total', width = 0.45)
plt.legend(loc = 'best', fontsize=20)
